# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayeon6423/Analysis-of-Resource-Allocation-Efficiency-in-Manufacturing-Industry-Linked-to-Greenhouse-Gas-Data/blob/main/Modeling_total.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Load Library & Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 1-1. Load Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.diagnostic import het_white

# %% [markdown]
# ### 1-2. Data Load

# %%
file_path = '/content/drive/MyDrive/SSK_한국연구재단(2023)/(소논문)온실가스 데이터와 연계한 지역간 제조업 자원배분 효율성 분석/data/'
city_data = pd.read_csv(file_path + 'manu_city_data.csv')
seoul_gas = pd.read_csv(file_path + '온실가스 데이터/seoul.csv')
busan_gas = pd.read_csv(file_path + '온실가스 데이터/Busan.csv')
gwangju_gas = pd.read_csv(file_path + '온실가스 데이터/Gwangju.csv')
daegu_gas = pd.read_csv(file_path + '온실가스 데이터/Daegu.csv')
daejeon_gas = pd.read_csv(file_path + '온실가스 데이터/daejeon.csv')
incheon_gas = pd.read_csv(file_path + '온실가스 데이터/Incheon.csv')
ulsan_gas = pd.read_csv(file_path + '온실가스 데이터/Ulsan.csv')

# %%
city_mapping = {11:'서울',
                21:'부산',
                22:'대구',
                23:'인천',
                24:'광주',
                25:'대전',
                26:'울산'}
city_data['c_city'].replace(city_mapping, inplace=True)

# %% [markdown]
# ### 1-3. data 명세
#
# - Product function : Y = A * L^alpha * K^beta * E^(1-alpha-beta)
# - Labor : pay1 + pay3
# - Kapital : (fasset_b + fasset_e) / 2
# - Eenergy : cost_fuel + cost_elec
# - Y(productivity) : vadd

# %%
city_data = city_data[['id','c1','c2','c3','year','c_city','pay1','pay3','fasset_b','fasset_e','cost_fuel','cost_elec','vadd']]

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# ### 2-1. 결측치 제거

# %%
# 결측치가 있는 행 제거
city_data = city_data.dropna()
# 결측치 확인
city_data.isnull().sum()
# Out:
# id           0
# c1           0
# c2           0
# c3           0
# year         0
# c_city       0
# pay1         0
# pay3         0
# fasset_b     0
# fasset_e     0
# cost_fuel    0
# cost_elec    0
# vadd         0
# dtype: int64

# %% [markdown]
# ### 2-2. 변수 생성

# %%
city_data['Labor'] = city_data['pay1'] + city_data['pay3']
city_data['Kapital'] = (city_data['fasset_b'] + city_data['fasset_b']) / 2
city_data['Energy'] = city_data['cost_fuel'] + city_data['cost_elec']

# %% [markdown]
# ### 2-3. 실질 변수 변환
# - 제조업 생산자물가지수 : 119.84
# - 실질변수 = 명목변수 / 제조업 생산자물가지수

# %%
price_index = 119.84
city_data['Labor_real'] = city_data['Labor'] / price_index
city_data['Kapital_real'] = city_data['Kapital'] / price_index
city_data['Energy_real'] = city_data['Energy'] / price_index
city_data['productivity_real'] = city_data['vadd'] / price_index

# %% [markdown]
# ### 2-4. 각 변수 값 / 2자릿수 기준 산업평균 값

# %%
# 산업코드(c2,c3) 분류의 가중평균 값(가중치 : 부가가치)
labor_weight_mean = city_data.groupby(['c2','c3']).apply(lambda x: (x['Labor_real'] * x['vadd']).sum() / x['vadd'].sum())
kapital_weight_mean = city_data.groupby(['c2','c3']).apply(lambda x: (x['Kapital_real'] * x['vadd']).sum() / x['vadd'].sum())
energy_weight_mean = city_data.groupby(['c2','c3']).apply(lambda x: (x['Energy_real'] * x['vadd']).sum() / x['vadd'].sum())
productivity_weight_mean = city_data.groupby(['c2','c3']).apply(lambda x: (x['productivity_real'] * x['vadd']).sum() / x['vadd'].sum())
print(productivity_weight_mean)
# Out:
# c2  c3
# 7   0      14.787239
#     1      85.671517
#     2     108.025940
#     3     175.311866
# 10  0     548.068549
#              ...
# 36  3      33.752190
#     4      38.075441
#     5      11.405750
#     9      74.880631
# 37  0      31.523639
# Length: 179, dtype: float64

# %%
# 가중평균을 데이터프레임으로 변환
labor_weight_mean_df = labor_weight_mean.reset_index(name='labor_weight_mean')
kapital_weight_mean_df = kapital_weight_mean.reset_index(name='kapital_weight_mean')
energy_weight_mean_df = energy_weight_mean.reset_index(name='energy_weight_mean')
productivity_weight_mean_df = productivity_weight_mean.reset_index(name='productivity_weight_mean')

# %%
# 기존 데이터프레임에 'c2'와 'c3' 값을 기준으로 가중평균 값 병합
city_data =  city_data.merge(labor_weight_mean_df, on=['c2', 'c3'])
city_data =  city_data.merge(kapital_weight_mean_df, on=['c2', 'c3'])
city_data =  city_data.merge(energy_weight_mean_df, on=['c2', 'c3'])
city_data =  city_data.merge(productivity_weight_mean_df, on=['c2', 'c3'])

# %%
# 해당기업 값 / 산업코드 기준 가중평균 값
city_data['Labor_real_mean'] = city_data['Labor_real'] / city_data['labor_weight_mean']
city_data['Kapital_real_mean'] = city_data['Kapital_real'] / city_data['kapital_weight_mean']
city_data['Energy_real_mean'] = city_data['Energy_real'] / city_data['energy_weight_mean']
city_data['productivity_real_mean'] = city_data['productivity_real'] / city_data['productivity_weight_mean']

city_data[['productivity_real','productivity_weight_mean','productivity_real_mean']]
# Out:
#         productivity_real  productivity_weight_mean  productivity_real_mean
# 0                3.446262                323.694616                0.010647
# 1               19.367490                323.694616                0.059833
# 2               15.078438                323.694616                0.046582
# 3               32.459947                323.694616                0.100280
# 4                1.226636                323.694616                0.003789
# ...                   ...                       ...                     ...
# 585588          20.085113                 85.671517                0.234443
# 585589          47.488318                 85.671517                0.554307
# 585590          67.481642                 85.671517                0.787679
# 585591         253.996996                260.461241                0.975182
# 585592          -6.158211                260.461241               -0.023643
#
# [585593 rows x 3 columns]

# %% [markdown]
# ### 2-5. log변환

# %%
# 마이너스 무한대 방지를 위해서 +0.01
city_data['Labor_real_mean_log'] = np.log(city_data['Labor_real_mean']+0.01)
city_data['Kapital_real_mean_log'] = np.log(city_data['Kapital_real_mean']+0.01)
city_data['Energy_real_mean_log'] = np.log(city_data['Energy_real_mean']+0.01)
city_data['productivity_real_mean_log'] = np.log(city_data['productivity_real_mean']+0.01)
city_data = city_data.dropna()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# 행정지역 필터링
city = '서울'
city_name = 'seoul'
city_data_seoul = city_data[city_data['c_city'] == city]

city = '부산'
city_name = 'busan'
city_data_busan = city_data[city_data['c_city'] == city]

city = '광주'
city_name = 'gwangju'
city_data_gwangju = city_data[city_data['c_city'] == city]

city = '대전'
city_name = 'daejeon'
city_data_daejeon = city_data[city_data['c_city'] == city]

city = '대구'
city_name = 'daegu'
city_data_daegu = city_data[city_data['c_city'] == city]

city = '인천'
city_name = 'incheon'
city_data_incheon= city_data[city_data['c_city'] == city]

city = '울산'
city_name = 'ulsan'
city_data_ulsan= city_data[city_data['c_city'] == city]

# %% [markdown]
# ## 3. Regression Modeling

# %% [markdown]
# ### 3-1. Robustness Check(전체 기간, 전체 지역)

# %% [markdown]
# - OLS regression

# %%
# 종속변수 저장
target = city_data[['productivity_real_mean_log']]

# 독립변수 저장
x_data = city_data[['Labor_real_mean_log', 'Kapital_real_mean_log', 'Energy_real_mean_log']]

# 선형회귀분석을 위한 b0항(상수항) 추가
x_data_b0 = sm.add_constant(x_data, has_constant='add')

# 회귀모델 적합
model = sm.OLS(target, x_data_b0)
fitted_model = model.fit()

# 잔차항 계산
residuals = fitted_model.resid

# y_hat계산 : y_hat = beta0*X0 + beta1*X1 + beta2*X2 + beta3*X3
params = fitted_model.params
pred = np.dot(x_data_b0, params)
pred = pd.Series(pred)

# OLS 결과 출력
print(fitted_model.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.873
# Model:                                    OLS   Adj. R-squared:                  0.873
# Method:                         Least Squares   F-statistic:                 1.339e+06
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:21:36   Log-Likelihood:            -2.9135e+05
# No. Observations:                      584712   AIC:                         5.827e+05
# Df Residuals:                          584708   BIC:                         5.827e+05
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.5390      0.002   -313.262      0.000      -0.542      -0.536
# Labor_real_mean_log       0.7364      0.001   1029.326      0.000       0.735       0.738
# Kapital_real_mean_log     0.1556      0.001    221.583      0.000       0.154       0.157
# Energy_real_mean_log      0.0284      0.001     43.088      0.000       0.027       0.030
# ==============================================================================
# Omnibus:                    84861.272   Durbin-Watson:                   1.291
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1206247.673
# Skew:                          -0.182   Prob(JB):                         0.00
# Kurtosis:                      10.027   Cond. No.                         20.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
def plot_residuals(pred, residuals):
    plt.figure(figsize=(10, 6))
    plt.scatter(pred, residuals)
    plt.axhline(y=0, color='red', linestyle='dashed', linewidth=2)
    plt.title(f'Residuals Plot')
    plt.xlabel('Predicted Values')
    plt.ylabel('Residuals')
    plt.grid()
    plt.show()

# %%
# residual plot
plot_residuals(pred, residuals)

# %%
# 지정된 노동 비중, 자본 비중, 에너지 비중 사용
plt.figure(figsize=(18, 6))
beta0 = fitted_model.params['const']

# 첫 번째 서브플롯: Kapital vs Productivity
plt.subplot(131)
sns.scatterplot(x='Kapital_real_mean_log', y='productivity_real_mean_log', data=city_data, label='Actual Data')
plt.plot(x_data['Kapital_real_mean_log'], beta0 + 0.49 * x_data['Kapital_real_mean_log'], color='red', linewidth=2, label='Regression Line')
plt.plot(x_data['Kapital_real_mean_log'], x_data['Kapital_real_mean_log'], color='black', linewidth=2, linestyle='dashed', label='y = x Line')
plt.title('Kapital VS Productivity_ALL')
plt.xlabel('Kapital_real_mean_log')
plt.ylabel('productivity_real_mean_log')
plt.legend()
plt.grid()

# 두 번째 서브플롯: Labor vs Productivity
plt.subplot(132)
sns.scatterplot(x='Labor_real_mean_log', y='productivity_real_mean_log', data=city_data, label='Actual Data')
plt.plot(x_data['Labor_real_mean_log'], beta0 + 0.47 * x_data['Labor_real_mean_log'], color='red', linewidth=2, label='Regression Line')
plt.plot(x_data['Labor_real_mean_log'], x_data['Labor_real_mean_log'], color='black', linewidth=2, linestyle='dashed', label='y = x Line')
plt.title('Regression : Labor VS Productivity_ALL')
plt.xlabel('Labor_real_mean_log')
plt.ylabel('productivity_real_mean_log')
plt.legend()
plt.grid()

# 세 번째 서브플롯: Energy vs Productivity
plt.subplot(133)
sns.scatterplot(x='Energy_real_mean_log', y='productivity_real_mean_log', data=city_data, label='Actual Data')
plt.plot(x_data['Energy_real_mean_log'], beta0 + 0.04 * x_data['Energy_real_mean_log'], color='red', linewidth=2, label='Regression Line')
plt.plot(x_data['Energy_real_mean_log'], x_data['Energy_real_mean_log'], color='black', linewidth=2, linestyle='dashed', label='y = x Line')
plt.title('Regression : Energy VS Productivity_ALL')
plt.xlabel('Energy_real_mean_log')
plt.ylabel('productivity_real_mean_log')
plt.legend()
plt.grid()

# 서브플롯 간 간격 조정 및 그래프 표시
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3-2. 행정구역별 연도별 회귀분석 및 산포도

# %%
# 연도별로 회귀분석을 수행하는 함수 정의
def perform_regression(year, city_data):
    # 종속변수 저장
    target = city_data[['productivity_real_mean_log']]
    # 독립변수 저장
    x_data = city_data[['Labor_real_mean_log', 'Kapital_real_mean_log', 'Energy_real_mean_log']]
    # 선형회귀분석을 위한 b0항(상수항) 추가
    x_data_b0 = sm.add_constant(x_data, has_constant='add')
    # 회귀모델 적합
    model = sm.OLS(target, x_data_b0)
    fitted_model = model.fit()
    params = fitted_model.params
    # y_hat 계산
    pred = np.dot(x_data_b0, params)
    pred = pd.Series(pred)
    # OLS 결과 출력
    print(f"Regression Results for {year}:")
    print(fitted_model.summary())
    print("\n")

# 연도별로 산점도와 회귀선 시각화하는 함수 정의
def plot_scatter_and_regression(year, city_data, var, ax):
    sns.set(style="whitegrid")

    # 서브플롯에서 회귀선을 빨간색 점선으로 설정
    sns.regplot(x=var, y='productivity_real_mean_log', data=city_data,
                line_kws={'color': 'red', 'linestyle': '--'}, ax=ax)

    # (0, 0)을 지나는 검은색 점선 추가
    ax.plot([city_data[var].min(), city_data[var].max()],
             [city_data[var].min(), city_data[var].max()],
             linestyle='--', color='black', linewidth=2)

    ax.set_title(f'{city_name}_{year}_{var}')

# 연도
years = [1999, 2009, 2019]
var = 'Energy_real_mean_log'

# %% [markdown]
# - 행정구역 : 서울

# %%
# 행정지역 필터링
city = '서울'
city_name = 'seoul'
city_data_seoul = city_data[city_data['c_city'] == city]

# %%
# 연도별로 회귀분석 실행
for year in years:
    city_data_year = city_data[city_data['year'] == year]
    perform_regression(year, city_data_year)
# Out:
# Regression Results for 1999:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.870
# Model:                                    OLS   Adj. R-squared:                  0.870
# Method:                         Least Squares   F-statistic:                 9.574e+04
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:02   Log-Likelihood:                -16126.
# No. Observations:                       42983   AIC:                         3.226e+04
# Df Residuals:                           42979   BIC:                         3.230e+04
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4901      0.007    -73.864      0.000      -0.503      -0.477
# Labor_real_mean_log       0.7231      0.003    252.354      0.000       0.718       0.729
# Kapital_real_mean_log     0.1944      0.003     76.547      0.000       0.189       0.199
# Energy_real_mean_log      0.0019      0.003      0.750      0.453      -0.003       0.007
# ==============================================================================
# Omnibus:                     6942.694   Durbin-Watson:                   1.337
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            53071.966
# Skew:                           0.566   Prob(JB):                         0.00
# Kurtosis:                       8.325   Cond. No.                         25.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2009:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.843
# Model:                                    OLS   Adj. R-squared:                  0.843
# Method:                         Least Squares   F-statistic:                 3.375e+04
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:02   Log-Likelihood:                -12804.
# No. Observations:                       18831   AIC:                         2.562e+04
# Df Residuals:                           18827   BIC:                         2.565e+04
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4144      0.010    -40.804      0.000      -0.434      -0.395
# Labor_real_mean_log       0.7897      0.004    179.445      0.000       0.781       0.798
# Kapital_real_mean_log     0.1421      0.004     34.019      0.000       0.134       0.150
# Energy_real_mean_log      0.0347      0.004      8.886      0.000       0.027       0.042
# ==============================================================================
# Omnibus:                     3052.701   Durbin-Watson:                   1.345
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37859.518
# Skew:                          -0.389   Prob(JB):                         0.00
# Kurtosis:                       9.903   Cond. No.                         17.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2019:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.857
# Model:                                    OLS   Adj. R-squared:                  0.857
# Method:                         Least Squares   F-statistic:                 2.808e+04
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:02   Log-Likelihood:                -9370.6
# No. Observations:                       14012   AIC:                         1.875e+04
# Df Residuals:                           14008   BIC:                         1.878e+04
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.6288      0.010    -64.986      0.000      -0.648      -0.610
# Labor_real_mean_log       0.7661      0.005    159.754      0.000       0.757       0.775
# Kapital_real_mean_log     0.1116      0.004     26.154      0.000       0.103       0.120
# Energy_real_mean_log      0.0584      0.004     13.769      0.000       0.050       0.067
# ==============================================================================
# Omnibus:                     2639.154   Durbin-Watson:                   1.240
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18201.373
# Skew:                          -0.729   Prob(JB):                         0.00
# Kurtosis:                       8.390   Cond. No.                         13.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 1행 3열의 서브플롯을 생성
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, year in enumerate(years):
    city_data_year = city_data_seoul[city_data_seoul['year'] == year]
    plot_scatter_and_regression(year, city_data_year, var, ax=axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# - 행정구역 : 부산

# %%
# 행정지역 필터링
city = '부산'
city_name = 'busan'
city_data_busan = city_data[city_data['c_city'] == city]

# %%
# 연도별로 회귀분석 실행
for year in years:
    city_data_year = city_data_busan[city_data_busan['year'] == year]
    perform_regression(year, city_data_year)
# Out:
# Regression Results for 1999:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.880
# Model:                                    OLS   Adj. R-squared:                  0.880
# Method:                         Least Squares   F-statistic:                 2.119e+04
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:04   Log-Likelihood:                -3424.0
# No. Observations:                        8646   AIC:                             6856.
# Df Residuals:                            8642   BIC:                             6884.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4641      0.015    -31.932      0.000      -0.493      -0.436
# Labor_real_mean_log       0.6934      0.006    111.961      0.000       0.681       0.706
# Kapital_real_mean_log     0.1859      0.006     31.572      0.000       0.174       0.197
# Energy_real_mean_log      0.0444      0.006      7.631      0.000       0.033       0.056
# ==============================================================================
# Omnibus:                      775.718   Durbin-Watson:                   1.187
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5413.425
# Skew:                           0.025   Prob(JB):                         0.00
# Kurtosis:                       6.876   Cond. No.                         24.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2009:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.836
# Model:                                    OLS   Adj. R-squared:                  0.836
# Method:                         Least Squares   F-statistic:                     6464.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:04   Log-Likelihood:                -2471.7
# No. Observations:                        3801   AIC:                             4951.
# Df Residuals:                            3797   BIC:                             4976.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4967      0.023    -21.897      0.000      -0.541      -0.452
# Labor_real_mean_log       0.7435      0.010     71.900      0.000       0.723       0.764
# Kapital_real_mean_log     0.1462      0.009     15.656      0.000       0.128       0.165
# Energy_real_mean_log      0.0569      0.009      6.125      0.000       0.039       0.075
# ==============================================================================
# Omnibus:                     1428.203   Durbin-Watson:                   1.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32119.373
# Skew:                          -1.253   Prob(JB):                         0.00
# Kurtosis:                      17.019   Cond. No.                         17.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2019:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.872
# Model:                                    OLS   Adj. R-squared:                  0.872
# Method:                         Least Squares   F-statistic:                     6785.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:04   Log-Likelihood:                -1781.4
# No. Observations:                        2995   AIC:                             3571.
# Df Residuals:                            2991   BIC:                             3595.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.6924      0.020    -35.051      0.000      -0.731      -0.654
# Labor_real_mean_log       0.7308      0.011     69.120      0.000       0.710       0.752
# Kapital_real_mean_log     0.1216      0.009     13.828      0.000       0.104       0.139
# Energy_real_mean_log      0.0687      0.009      7.448      0.000       0.051       0.087
# ==============================================================================
# Omnibus:                      546.771   Durbin-Watson:                   1.163
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2833.660
# Skew:                          -0.772   Prob(JB):                         0.00
# Kurtosis:                       7.508   Cond. No.                         13.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 1행 3열의 서브플롯을 생성
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, year in enumerate(years):
    city_data_year = city_data_busan[city_data_busan['year'] == year]
    plot_scatter_and_regression(year, city_data_year, var, ax=axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# - 행정구역 : 광주

# %%
# 행정지역 필터링
city = '광주'
city_name = 'gwangju'
city_data_gwangju = city_data[city_data['c_city'] == city]

# %%
# 연도별로 회귀분석 실행
for year in years:
    city_data_year = city_data_gwangju[city_data_gwangju['year'] == year]
    perform_regression(year, city_data_year)
# Out:
# Regression Results for 1999:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.906
# Model:                                    OLS   Adj. R-squared:                  0.906
# Method:                         Least Squares   F-statistic:                     4031.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:06   Log-Likelihood:                -320.48
# No. Observations:                        1259   AIC:                             649.0
# Df Residuals:                            1255   BIC:                             669.5
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.5087      0.030    -16.701      0.000      -0.568      -0.449
# Labor_real_mean_log       0.6774      0.018     36.867      0.000       0.641       0.713
# Kapital_real_mean_log     0.1508      0.014     10.747      0.000       0.123       0.178
# Energy_real_mean_log      0.0791      0.015      5.292      0.000       0.050       0.108
# ==============================================================================
# Omnibus:                      143.140   Durbin-Watson:                   1.531
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              821.680
# Skew:                           0.347   Prob(JB):                    3.75e-179
# Kurtosis:                       6.896   Cond. No.                         22.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2009:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.843
# Model:                                    OLS   Adj. R-squared:                  0.843
# Method:                         Least Squares   F-statistic:                     1836.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:06   Log-Likelihood:                -687.86
# No. Observations:                        1030   AIC:                             1384.
# Df Residuals:                            1026   BIC:                             1403.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4628      0.040    -11.551      0.000      -0.541      -0.384
# Labor_real_mean_log       0.7494      0.021     35.203      0.000       0.708       0.791
# Kapital_real_mean_log     0.2039      0.021      9.569      0.000       0.162       0.246
# Energy_real_mean_log     -0.0133      0.018     -0.761      0.447      -0.048       0.021
# ==============================================================================
# Omnibus:                      180.198   Durbin-Watson:                   1.453
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1969.661
# Skew:                           0.438   Prob(JB):                         0.00
# Kurtosis:                       9.718   Cond. No.                         15.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2019:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.874
# Model:                                    OLS   Adj. R-squared:                  0.873
# Method:                         Least Squares   F-statistic:                     2286.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:06   Log-Likelihood:                -648.12
# No. Observations:                         995   AIC:                             1304.
# Df Residuals:                             991   BIC:                             1324.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.5629      0.032    -17.493      0.000      -0.626      -0.500
# Labor_real_mean_log       0.7328      0.018     40.198      0.000       0.697       0.769
# Kapital_real_mean_log     0.1584      0.019      8.413      0.000       0.121       0.195
# Energy_real_mean_log      0.0396      0.018      2.231      0.026       0.005       0.075
# ==============================================================================
# Omnibus:                       93.513   Durbin-Watson:                   1.525
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              572.508
# Skew:                           0.113   Prob(JB):                    4.80e-125
# Kurtosis:                       6.709   Cond. No.                         11.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 1행 3열의 서브플롯을 생성
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, year in enumerate(years):
    city_data_year = city_data_gwangju[city_data_gwangju['year'] == year]
    plot_scatter_and_regression(year, city_data_year, var, ax=axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# - 행정구역 : 대전

# %%
# 행정지역 필터링
city = '대전'
city_name = 'daejeon'
city_data_daejeon = city_data[city_data['c_city'] == city]

# %%
# 연도별로 회귀분석 실행
for year in years:
    city_data_year = city_data_daejeon[city_data_daejeon['year'] == year]
    perform_regression(year, city_data_year)
# Out:
# Regression Results for 1999:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.896
# Model:                                    OLS   Adj. R-squared:                  0.896
# Method:                         Least Squares   F-statistic:                     3404.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:07   Log-Likelihood:                -438.66
# No. Observations:                        1189   AIC:                             885.3
# Df Residuals:                            1185   BIC:                             905.6
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4111      0.034    -11.933      0.000      -0.479      -0.344
# Labor_real_mean_log       0.6608      0.018     36.105      0.000       0.625       0.697
# Kapital_real_mean_log     0.2335      0.015     15.520      0.000       0.204       0.263
# Energy_real_mean_log      0.0402      0.015      2.607      0.009       0.010       0.070
# ==============================================================================
# Omnibus:                       98.796   Durbin-Watson:                   1.346
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              552.681
# Skew:                           0.052   Prob(JB):                    9.70e-121
# Kurtosis:                       6.338   Cond. No.                         22.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2009:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.805
# Model:                                    OLS   Adj. R-squared:                  0.804
# Method:                         Least Squares   F-statistic:                     915.8
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):          8.69e-236
# Time:                                07:22:07   Log-Likelihood:                -548.00
# No. Observations:                         670   AIC:                             1104.
# Df Residuals:                             666   BIC:                             1122.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4383      0.058     -7.550      0.000      -0.552      -0.324
# Labor_real_mean_log       0.7411      0.028     26.861      0.000       0.687       0.795
# Kapital_real_mean_log     0.1523      0.028      5.526      0.000       0.098       0.206
# Energy_real_mean_log      0.0498      0.024      2.065      0.039       0.002       0.097
# ==============================================================================
# Omnibus:                       76.277   Durbin-Watson:                   1.613
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              392.243
# Skew:                          -0.348   Prob(JB):                     6.69e-86
# Kurtosis:                       6.683   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2019:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.828
# Model:                                    OLS   Adj. R-squared:                  0.827
# Method:                         Least Squares   F-statistic:                     813.6
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):          2.63e-193
# Time:                                07:22:07   Log-Likelihood:                -400.42
# No. Observations:                         511   AIC:                             808.8
# Df Residuals:                             507   BIC:                             825.8
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.6163      0.054    -11.311      0.000      -0.723      -0.509
# Labor_real_mean_log       0.7026      0.028     25.357      0.000       0.648       0.757
# Kapital_real_mean_log     0.0956      0.028      3.405      0.001       0.040       0.151
# Energy_real_mean_log      0.1222      0.026      4.769      0.000       0.072       0.173
# ==============================================================================
# Omnibus:                       25.788   Durbin-Watson:                   1.451
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.690
# Skew:                          -0.013   Prob(JB):                     1.35e-17
# Kurtosis:                       4.910   Cond. No.                         12.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 1행 3열의 서브플롯을 생성
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, year in enumerate(years):
    city_data_year = city_data_daejeon[city_data_daejeon['year'] == year]
    plot_scatter_and_regression(year, city_data_year, var, ax=axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# - 행정구역 : 대구

# %%
# 행정지역 필터링
city = '대구'
city_name = 'daegu'
city_data_daegu = city_data[city_data['c_city'] == city]

# %%
# 연도별로 회귀분석 실행
for year in years:
    city_data_year = city_data_daegu[city_data_daegu['year'] == year]
    perform_regression(year, city_data_year)
# Out:
# Regression Results for 1999:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.883
# Model:                                    OLS   Adj. R-squared:                  0.883
# Method:                         Least Squares   F-statistic:                 1.496e+04
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:09   Log-Likelihood:                -1754.4
# No. Observations:                        5923   AIC:                             3517.
# Df Residuals:                            5919   BIC:                             3544.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.6129      0.015    -41.115      0.000      -0.642      -0.584
# Labor_real_mean_log       0.7159      0.008     90.359      0.000       0.700       0.731
# Kapital_real_mean_log     0.1093      0.006     17.440      0.000       0.097       0.122
# Energy_real_mean_log      0.0640      0.006     10.271      0.000       0.052       0.076
# ==============================================================================
# Omnibus:                     1220.610   Durbin-Watson:                   1.527
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7029.333
# Skew:                           0.862   Prob(JB):                         0.00
# Kurtosis:                       8.051   Cond. No.                         22.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2009:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.868
# Model:                                    OLS   Adj. R-squared:                  0.867
# Method:                         Least Squares   F-statistic:                     6201.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:09   Log-Likelihood:                -1643.4
# No. Observations:                        2843   AIC:                             3295.
# Df Residuals:                            2839   BIC:                             3319.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4249      0.022    -19.618      0.000      -0.467      -0.382
# Labor_real_mean_log       0.8078      0.012     68.339      0.000       0.785       0.831
# Kapital_real_mean_log     0.0819      0.010      7.873      0.000       0.062       0.102
# Energy_real_mean_log      0.0673      0.009      7.222      0.000       0.049       0.086
# ==============================================================================
# Omnibus:                      984.475   Durbin-Watson:                   1.488
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21874.050
# Skew:                          -1.107   Prob(JB):                         0.00
# Kurtosis:                      16.407   Cond. No.                         14.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2019:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.887
# Model:                                    OLS   Adj. R-squared:                  0.886
# Method:                         Least Squares   F-statistic:                     6323.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:09   Log-Likelihood:                -1249.7
# No. Observations:                        2432   AIC:                             2507.
# Df Residuals:                            2428   BIC:                             2531.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.6015      0.019    -31.607      0.000      -0.639      -0.564
# Labor_real_mean_log       0.7538      0.011     65.887      0.000       0.731       0.776
# Kapital_real_mean_log     0.1021      0.009     11.458      0.000       0.085       0.120
# Energy_real_mean_log      0.0801      0.009      9.266      0.000       0.063       0.097
# ==============================================================================
# Omnibus:                      525.441   Durbin-Watson:                   1.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3493.044
# Skew:                          -0.851   Prob(JB):                         0.00
# Kurtosis:                       8.619   Cond. No.                         12.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 1행 3열의 서브플롯을 생성
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, year in enumerate(years):
    city_data_year = city_data_daegu[city_data_daegu['year'] == year]
    plot_scatter_and_regression(year, city_data_year, var, ax=axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# - 행정구역 : 인천

# %%
# 행정지역 필터링
city = '인천'
city_name = 'incheon'
city_data_incheon= city_data[city_data['c_city'] == city]

# %%
# 연도별로 회귀분석 실행
for year in years:
    city_data_year = city_data_incheon[city_data_incheon['year'] == year]
    perform_regression(year, city_data_year)
# Out:
# Regression Results for 1999:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.894
# Model:                                    OLS   Adj. R-squared:                  0.894
# Method:                         Least Squares   F-statistic:                 2.051e+04
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:10   Log-Likelihood:                -2493.9
# No. Observations:                        7330   AIC:                             4996.
# Df Residuals:                            7326   BIC:                             5023.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4176      0.014    -29.399      0.000      -0.445      -0.390
# Labor_real_mean_log       0.6908      0.007     93.906      0.000       0.676       0.705
# Kapital_real_mean_log     0.1804      0.006     29.005      0.000       0.168       0.193
# Energy_real_mean_log      0.0567      0.006      9.284      0.000       0.045       0.069
# ==============================================================================
# Omnibus:                     1218.612   Durbin-Watson:                   1.447
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16100.379
# Skew:                           0.381   Prob(JB):                         0.00
# Kurtosis:                      10.221   Cond. No.                         23.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2009:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.847
# Model:                                    OLS   Adj. R-squared:                  0.847
# Method:                         Least Squares   F-statistic:                     7858.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:10   Log-Likelihood:                -2691.0
# No. Observations:                        4255   AIC:                             5390.
# Df Residuals:                            4251   BIC:                             5415.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4498      0.020    -22.454      0.000      -0.489      -0.411
# Labor_real_mean_log       0.7901      0.010     82.612      0.000       0.771       0.809
# Kapital_real_mean_log     0.1271      0.008     15.444      0.000       0.111       0.143
# Energy_real_mean_log      0.0300      0.008      3.583      0.000       0.014       0.046
# ==============================================================================
# Omnibus:                      456.667   Durbin-Watson:                   1.312
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3302.778
# Skew:                          -0.233   Prob(JB):                         0.00
# Kurtosis:                       7.291   Cond. No.                         16.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2019:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.837
# Model:                                    OLS   Adj. R-squared:                  0.836
# Method:                         Least Squares   F-statistic:                     5596.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:10   Log-Likelihood:                -2267.3
# No. Observations:                        3282   AIC:                             4543.
# Df Residuals:                            3278   BIC:                             4567.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.6937      0.021    -33.415      0.000      -0.734      -0.653
# Labor_real_mean_log       0.7552      0.011     66.322      0.000       0.733       0.778
# Kapital_real_mean_log     0.0852      0.009      9.406      0.000       0.067       0.103
# Energy_real_mean_log      0.0716      0.009      7.587      0.000       0.053       0.090
# ==============================================================================
# Omnibus:                     1172.462   Durbin-Watson:                   1.131
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9976.705
# Skew:                          -1.456   Prob(JB):                         0.00
# Kurtosis:                      11.030   Cond. No.                         13.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 1행 3열의 서브플롯을 생성
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, year in enumerate(years):
    city_data_year = city_data_incheon[city_data_incheon['year'] == year]
    plot_scatter_and_regression(year, city_data_year, var, ax=axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# - 행정구역 : 울산

# %%
# 행정지역 필터링
city = '울산'
city_name = 'ulsan'
city_data_ulsan= city_data[city_data['c_city'] == city]

# %%
# 연도별로 회귀분석 실행
for year in years:
    city_data_year = city_data_ulsan[city_data_ulsan['year'] == year]
    perform_regression(year, city_data_year)
# Out:
# Regression Results for 1999:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.901
# Model:                                    OLS   Adj. R-squared:                  0.901
# Method:                         Least Squares   F-statistic:                     3495.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:12   Log-Likelihood:                -615.00
# No. Observations:                        1150   AIC:                             1238.
# Df Residuals:                            1146   BIC:                             1258.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.3482      0.033    -10.420      0.000      -0.414      -0.283
# Labor_real_mean_log       0.7016      0.013     52.593      0.000       0.675       0.728
# Kapital_real_mean_log     0.1826      0.016     11.157      0.000       0.150       0.215
# Energy_real_mean_log      0.0588      0.017      3.565      0.000       0.026       0.091
# ==============================================================================
# Omnibus:                      243.644   Durbin-Watson:                   1.707
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4307.337
# Skew:                          -0.466   Prob(JB):                         0.00
# Kurtosis:                      12.435   Cond. No.                         17.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2009:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.852
# Model:                                    OLS   Adj. R-squared:                  0.852
# Method:                         Least Squares   F-statistic:                     2285.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:12   Log-Likelihood:                -890.51
# No. Observations:                        1191   AIC:                             1789.
# Df Residuals:                            1187   BIC:                             1809.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2312      0.038     -6.154      0.000      -0.305      -0.157
# Labor_real_mean_log       0.8042      0.014     59.526      0.000       0.778       0.831
# Kapital_real_mean_log     0.1316      0.018      7.489      0.000       0.097       0.166
# Energy_real_mean_log      0.0757      0.017      4.447      0.000       0.042       0.109
# ==============================================================================
# Omnibus:                      163.324   Durbin-Watson:                   1.502
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1172.474
# Skew:                          -0.396   Prob(JB):                    2.52e-255
# Kurtosis:                       7.796   Cond. No.                         14.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Regression Results for 2019:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     productivity_real_mean_log   R-squared:                       0.863
# Model:                                    OLS   Adj. R-squared:                  0.863
# Method:                         Least Squares   F-statistic:                     2671.
# Date:                        Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                                07:22:12   Log-Likelihood:                -906.09
# No. Observations:                        1275   AIC:                             1820.
# Df Residuals:                            1271   BIC:                             1841.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.5775      0.031    -18.918      0.000      -0.637      -0.518
# Labor_real_mean_log       0.8121      0.012     65.456      0.000       0.788       0.836
# Kapital_real_mean_log     0.0967      0.015      6.325      0.000       0.067       0.127
# Energy_real_mean_log      0.0457      0.016      2.902      0.004       0.015       0.077
# ==============================================================================
# Omnibus:                      214.540   Durbin-Watson:                   1.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1356.873
# Skew:                          -0.613   Prob(JB):                    2.28e-295
# Kurtosis:                       7.903   Cond. No.                         12.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 1행 3열의 서브플롯을 생성
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, year in enumerate(years):
    city_data_year = city_data_ulsan[city_data_ulsan['year'] == year]
    plot_scatter_and_regression(year, city_data_year, var, ax=axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4-1.실질부가가치 성장률과 온실가스 배출량 성장률

# %% [markdown]
# 실질 부가가치 성장률 도출 방법
#
# * 기업의 실질부가가치 = 기업의 부가가치 / 제조업 대표 물가지수(119.84)
# * 기업의 실질부가가치 변화율
# * 연도별 기업의 실질 부가가치 변화율의 중앙값
# * 지역 순서 : 서울,부산,광주,대전,대구,인천,울산

# %%
# 새로운 그림(figure)을 생성하고 서브플롯을 추가합니다.
fig, ax1 = plt.subplots()

# 첫 번째 데이터 시리즈를 첫 번째 Y 축에 그립니다.
ax1.plot([1, 2, 3, 4], [10, 20, 15, 25], 'b-', label='Data Series 1')
ax1.set_xlabel('X Axis')
ax1.set_ylabel('Y Axis 1', color='b')

# ax1과 동일한 X 축을 가지면서 새로운 Y 축을 생성합니다.
ax2 = ax1.twinx()

# 두 번째 데이터 시리즈를 새로운 Y 축에 그립니다.
ax2.plot([1, 2, 3, 4], [50, 40, 45, 55], 'r--', label='Data Series 2')
ax2.set_ylabel('Y Axis 2', color='r')

# 범례를 추가합니다.
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.show()

# %%
def made_real_vadd_growth(df):
    manu_price_index = 119.84
    df['real_vadd_growth'] = df['vadd'] / manu_price_index
    df['real_vadd_growth'] = df['real_vadd_growth'].pct_change() * 100
    real_price_growth = pd.DataFrame(df.groupby('year')['real_vadd_growth'].median())
    return real_price_growth

def real_vadd_growth_gas_graph(city_df, gas_df, city_name):
    vadd_df = made_real_vadd_growth(city_df).reset_index().rename(columns={'year': 'YEAR'})
    tmp = gas_df[9:][['YEAR', 'MADE']].reset_index(drop=True)
    merge_df = pd.merge(tmp, vadd_df, on='YEAR')

    # graph size
    plt.figure(figsize=(10, 5))

    # first y-axis(manufacture gas emission)
    ax1 = plt.gca()
    ax1.plot(merge_df['YEAR'], merge_df['MADE'], label='Gas_Emission', color='blue')
    ax1.set_ylabel('Gas_Emission')
    ax1.tick_params(axis='y')

    # second y-axis(real_add_growth)
    ax2 = ax1.twinx()
    ax2.plot(merge_df['YEAR'], merge_df['real_vadd_growth'], label='Real_Vadd_Growth', color='green')
    ax2.set_ylabel('Real_Vadd_Growth')
    ax2.tick_params(axis='y')

    # x-axis (year)
    plt.xlabel('YEAR')

    # set legend
    lines_1, labels_1 = ax1.get_legend_handles_labels()
    lines_2, labels_2 = ax2.get_legend_handles_labels()
    plt.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper left', bbox_to_anchor=(0.05, 0.95))

    plt.title(f'{city_name}_Gas Emission & Real Vadd Growth')
    plt.ylim(-5, 5)
    plt.grid(True)
    ax1.grid(which='both', axis='both')
    ax2.grid(which='both', axis='both')

    plt.show()

# %%
# 서울
city_name = 'Seoul'
real_vadd_growth_gas_graph(city_data_seoul,seoul_gas,city_name)
# Out:
# <ipython-input-22-2e8efd026160>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['vadd'] / manu_price_index
# <ipython-input-22-2e8efd026160>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['real_vadd_growth'].pct_change() * 100

# %%
# 부산
city_name = 'Busan'
real_vadd_growth_gas_graph(city_data_busan,busan_gas,city_name)
# Out:
# <ipython-input-22-2e8efd026160>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['vadd'] / manu_price_index
# <ipython-input-22-2e8efd026160>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['real_vadd_growth'].pct_change() * 100

# %%
# 광주
city_name = 'Gwangju'
real_vadd_growth_gas_graph(city_data_gwangju,gwangju_gas,city_name)
# Out:
# <ipython-input-22-2e8efd026160>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['vadd'] / manu_price_index
# <ipython-input-22-2e8efd026160>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['real_vadd_growth'].pct_change() * 100

# %%
# 대전
city_name = 'Daejeon'
real_vadd_growth_gas_graph(city_data_daejeon,daejeon_gas,city_name)
# Out:
# <ipython-input-22-2e8efd026160>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['vadd'] / manu_price_index
# <ipython-input-22-2e8efd026160>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['real_vadd_growth'].pct_change() * 100

# %%
# 대구
city_name = 'Daegu'
real_vadd_growth_gas_graph(city_data_daegu,daegu_gas,city_name)
# Out:
# <ipython-input-22-2e8efd026160>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['vadd'] / manu_price_index
# <ipython-input-22-2e8efd026160>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['real_vadd_growth'].pct_change() * 100

# %%
# 인천
city_name = 'Incheon'
real_vadd_growth_gas_graph(city_data_incheon,incheon_gas,city_name)
# Out:
# <ipython-input-22-2e8efd026160>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['vadd'] / manu_price_index
# <ipython-input-22-2e8efd026160>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['real_vadd_growth'].pct_change() * 100

# %%
# 울산
city_name = 'ulsan'
real_vadd_growth_gas_graph(city_data_ulsan,ulsan_gas,city_name)
# Out:
# <ipython-input-22-2e8efd026160>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['vadd'] / manu_price_index
# <ipython-input-22-2e8efd026160>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['real_vadd_growth'] = df['real_vadd_growth'].pct_change() * 100
